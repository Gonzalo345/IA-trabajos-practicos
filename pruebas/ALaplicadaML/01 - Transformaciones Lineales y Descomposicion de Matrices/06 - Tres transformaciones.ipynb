# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
# %run "../funciones_auxiliares/graficarVectores.ipynb"
# %run "../funciones_auxiliares/graficarMatriz.ipynb"

# %%
orange_light = '#FF9A13'
blue_light = '#1190FF'

# %%
A = np.array([[3,7],[5,2]])
print(A)
# Out:
# [[3 7]
#  [5 2]]

# %%
print('circulo unitario:')
graficarMatriz(np.array([[1, 0], [0, 1]]))

plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.show()

print('Circolo unitario trasformado:')
graficarMatriz(A)

plt.xlim(-8, 8)
plt.ylim(-8, 8)
plt.show
# Out:
# circulo unitario:
# Circolo unitario trasformado:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
autovalores, autovectores = np.linalg.eig(A)
print(autovalores)
print(autovectores)

# %%
A_calc = autovectores.dot(np.diag(autovalores)).dot(np.linalg.inv(autovectores))

# %%
print(A_calc)

# %%
A = np.array([[3,2],[2,3]])

# %%
print(A == A.T)

# %%
autovalores, autovectores = np.linalg.eig(A)
print(autovalores)
print(autovectores)

# %% [markdown]
# Es mucho mas facil calcular una transpuesta que una inversa

# %%
A_calc = autovectores.dot(np.diag(autovalores)).dot(autovectores.T)
print(A_calc)
